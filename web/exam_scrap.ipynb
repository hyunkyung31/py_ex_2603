# %%
# requests 모듈 -> 웹페이지를 요청하고 응답데이터를 받을 수 있다
import requests as req
from bs4 import BeautifulSoup # html 해석기 (파이썬 언어로 번역해주는)


'''
#요청시 오류났을 때 아래 문구를 입력 해주세요
User-Agent : 웹 요청 시 프로그램이 아니라 브라우저 처럼 보이게 설정
request_headers = {'User-Agent': ('Mozilla/5.0 (Windows NT 10.0;Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'), }  
=> 나도 크롬같은 브라우저 중에 하나야 걱정 ㄴㄴ해

response = req.get('https://www.naver.com', request_headers)
'''


response = req.get('https://www.naver.com')
# print(response)

html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# print(html_doc)

soup = BeautifulSoup(html_doc, 'html.parser')

# soup을 이용해서 html_doc 문자열 파싱, 그 내용을 soupt 변수에 대입을 하겠다 
# 파싱 : 입력(문서, 코드, 데이터)를 읽어 의미 있는 단위로 분해하고 그 구조를 정리해 컴퓨터가 이해하기 쉬운
# 형태로 반드는 과정

a_list = soup.select('a') #a라는걸 선택하겠다

print("====a 태그들 리스트===")
print(a_list)

print("====a 태그들 리스트 중 첫번째===")
print(a_list[0])

print("====a 태그들 리스트 첫번째 텍스트만 가져온다===")
print(a_list[0].text)

print("====a 태그들 리스트 중 첫번째 링크===")
print(a_list[0]['href']) #css 속성을 선택할때는 대괄호 []

print("====a 태그 리스트에 있는 텍스트 모두 출력 ===")
for a in a_list :
    print(a.text)

print("=== a태그 리스트에 있는 링크 모두 출력 ===")
for link in a_list:
    print(link['href'])
# Out:
# ====a 태그들 리스트===
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>, <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>, <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]
# ====a 태그들 리스트 중 첫번째===
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
# ====a 태그들 리스트 첫번째 텍스트만 가져온다===
# Elsie
# ====a 태그들 리스트 중 첫번째 링크===
# http://example.com/elsie
# ====a 태그 리스트에 있는 텍스트 모두 출력 ===
# Elsie
# Lacie
# Tillie
# === a태그 리스트에 있는 링크 모두 출력 ===
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
'''
html 

#부모 엘리먼트
<div>
#자식 엘리먼트
    <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
  <div>
  #후손 
      <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>
</div>

CSS

1.태그 선택
a { color: red; }

2. 후손선택
div a { color: red; }

3. 자식선택
div > a { color: red; }

4. class 선택
.sister { color: red; }

5. id 선택 (하나밖에 없음)
#link1 { color: red; }
