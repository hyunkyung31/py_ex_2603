# %%
import ex1

ex1.funA()
# Out:
# 'A 실행'

# %%
from ex1 import funA, funB

# funA()
# funB()
# 이런식으로 호출하면 마지막 것만 호출이 된다

# %%
import sys
print(sys.path)
# Out:
# ['c:\\Users\\202\\AppData\\Local\\Programs\\Python\\Python314\\python314.zip', 'c:\\Users\\202\\AppData\\Local\\Programs\\Python\\Python314\\DLLs', 'c:\\Users\\202\\AppData\\Local\\Programs\\Python\\Python314\\Lib', 'c:\\Users\\202\\AppData\\Local\\Programs\\Python\\Python314', '', 'C:\\Users\\202\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Users\\202\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages']
